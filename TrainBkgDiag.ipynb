# %% [markdown]
# # Hit classification

# %% [markdown]
# In this notebook we use Keras and XGBoost to distinguish between hits from conversion electrons and hits from other particles

# %%
import uproot 
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import os
import datetime
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, ReLU
from tensorflow.keras.optimizers import SGD
import tensorflow.keras.layers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier
# Out:
# 2023-02-10 14:25:37.096650: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-10 14:25:37.321650: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/ifdhc/v2_6_10/Linux64bit-3-10-2-17/lib:/mu2e/app/users/myucel/mu2e-dev/build/sl7-prof-e20-p037/Offline/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cryptopp/v08_02_00/Linux64bit+3.10-2.17-e20-prof:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib:/cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/curl/v7_64_1/Linux64bit-3-10/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cry/v1_7p/Linux64bit+3.10-2.17-e20-prof/cry_v1.7/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/KinKal/v02_03_01/slf7.x86_64.e20.p3913.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/BTrk/v1_02_37/slf7.x86_64.e20.prof.p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core_mu2e/v1_08_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pcie_linux_kernel_module/v2_07_00/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core/v3_09_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/TRACE/v3_17_05//lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/geant4/v4_10_7_p03b/Linux64bit+3.10-2.17-e20-mt-prof/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/xerces_c/v3_2_3c/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gallery/v1_20_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/xrootd/v5_4_3b/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pythia/v6_4_28u/Linux64bit+3.10-2.17-gcc930-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/postgresql/v14_5/Linux64bit+3.10-2.17-p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/openblas/v0_3_21/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/python/v3_9_13/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/libxml2/v2_9_12/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gsl/v2_7/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fftw/v3_3_10/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/root/v6_26_06/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art/v3_12_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas/v3_14_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/messagefacility/v2_09_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fhiclcpp/v4_17_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib/v3_16_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/sqlite/v3_39_02_00/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/hep_concurrency/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/tbb/v2021_7_0/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib_except/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/boost/v1_80_0/Linux64bit+3.10-2.17-e20-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/clhep/v2_4_5_3a/Linux64bit+3.10-2.17-e20-prof/lib
# 2023-02-10 14:25:37.321700: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-10 14:25:38.879656: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/ifdhc/v2_6_10/Linux64bit-3-10-2-17/lib:/mu2e/app/users/myucel/mu2e-dev/build/sl7-prof-e20-p037/Offline/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cryptopp/v08_02_00/Linux64bit+3.10-2.17-e20-prof:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib:/cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/curl/v7_64_1/Linux64bit-3-10/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cry/v1_7p/Linux64bit+3.10-2.17-e20-prof/cry_v1.7/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/KinKal/v02_03_01/slf7.x86_64.e20.p3913.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/BTrk/v1_02_37/slf7.x86_64.e20.prof.p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core_mu2e/v1_08_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pcie_linux_kernel_module/v2_07_00/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core/v3_09_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/TRACE/v3_17_05//lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/geant4/v4_10_7_p03b/Linux64bit+3.10-2.17-e20-mt-prof/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/xerces_c/v3_2_3c/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gallery/v1_20_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/xrootd/v5_4_3b/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pythia/v6_4_28u/Linux64bit+3.10-2.17-gcc930-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/postgresql/v14_5/Linux64bit+3.10-2.17-p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/openblas/v0_3_21/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/python/v3_9_13/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/libxml2/v2_9_12/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gsl/v2_7/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fftw/v3_3_10/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/root/v6_26_06/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art/v3_12_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas/v3_14_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/messagefacility/v2_09_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fhiclcpp/v4_17_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib/v3_16_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/sqlite/v3_39_02_00/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/hep_concurrency/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/tbb/v2021_7_0/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib_except/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/boost/v1_80_0/Linux64bit+3.10-2.17-e20-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/clhep/v2_4_5_3a/Linux64bit+3.10-2.17-e20-prof/lib
# 2023-02-10 14:25:38.881496: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/ifdhc/v2_6_10/Linux64bit-3-10-2-17/lib:/mu2e/app/users/myucel/mu2e-dev/build/sl7-prof-e20-p037/Offline/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cryptopp/v08_02_00/Linux64bit+3.10-2.17-e20-prof:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib:/cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/curl/v7_64_1/Linux64bit-3-10/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cry/v1_7p/Linux64bit+3.10-2.17-e20-prof/cry_v1.7/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/KinKal/v02_03_01/slf7.x86_64.e20.p3913.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/BTrk/v1_02_37/slf7.x86_64.e20.prof.p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core_mu2e/v1_08_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pcie_linux_kernel_module/v2_07_00/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core/v3_09_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/TRACE/v3_17_05//lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/geant4/v4_10_7_p03b/Linux64bit+3.10-2.17-e20-mt-prof/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/xerces_c/v3_2_3c/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gallery/v1_20_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/xrootd/v5_4_3b/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pythia/v6_4_28u/Linux64bit+3.10-2.17-gcc930-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/postgresql/v14_5/Linux64bit+3.10-2.17-p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/openblas/v0_3_21/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/python/v3_9_13/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/libxml2/v2_9_12/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gsl/v2_7/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fftw/v3_3_10/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/root/v6_26_06/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art/v3_12_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas/v3_14_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/messagefacility/v2_09_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fhiclcpp/v4_17_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib/v3_16_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/sqlite/v3_39_02_00/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/hep_concurrency/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/tbb/v2021_7_0/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib_except/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/boost/v1_80_0/Linux64bit+3.10-2.17-e20-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/clhep/v2_4_5_3a/Linux64bit+3.10-2.17-e20-prof/lib
# 2023-02-10 14:25:38.881519: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# In our problem we have a different number of signal and background entries in our input dataset. There are several techniques avaialable for _unbalanced_ datasets. Here we are using the most naive one, which is just using $\min(N_{sig}, N_{bkg})$ events. Then, we divide our input into the _training_, _validation_, and _test_ datasets.  Note that the datasets must be pruned to the nearest multiple of the batch size, otherwise the gradient calculation fails.

# %%
input_dataset = np.empty
temp = np.empty
signal = np.empty
backgnd = np.empty
#filelist = os.environ['KKTrainBkgFiles']
filelist = "KKTrainBkgFiles.txt"
print("Using files in " + filelist)
files = open(filelist, 'r')
for filename in files:
    print("Processing: " + filename)    
    with uproot.open(filename) as file:
        bkgdiag = file["BD"]["bkgcdiag"].arrays()
        bkgdiag = bkgdiag[(bkgdiag['mvastat']>0)&((bkgdiag['pproc']==167)|(bkgdiag['pproc']<20))]
        clusterrho = bkgdiag['ClusterRho'].to_numpy()
        zmin = bkgdiag['ZMin'].to_numpy()
        zmax = bkgdiag['ZMax'].to_numpy()
        zgap = bkgdiag['ZGap'].to_numpy()
        nplanes = bkgdiag['NPlanes'].to_numpy()
        planefraction = bkgdiag['PlaneFraction'].to_numpy()
        nhits = bkgdiag['NHits'].to_numpy()
        pproc = bkgdiag['pproc'].to_numpy()
        #print("Processed file " + filename + " with %s hits"%hstate.shape[0])
        print("Processed file " + filename + " with %s hits"%nhits.shape[0])
        temp = np.vstack((clusterrho, zmin, zmax, zgap, nplanes, planefraction, nhits)).T
        if input_dataset is np.empty:
            input_dataset = temp
        else:
            input_dataset = np.concatenate((input_dataset, temp))
        sig = pproc<20
        bkg = pproc==167
        if signal is np.empty:
            signal = sig
            backgnd = bkg
        else:
            signal = np.concatenate((signal,sig))
            backgnd = np.concatenate((backgnd,bkg))
nclusters=len(input_dataset)
nsignal=signal.sum()
nbackgnd=backgnd.sum()
print("Total dataset %s hits, %s signal and %s background"%(nhits,nsignal,nbackgnd))
# Out:
# Using files in KKTrainBkgFiles.txt
# Processing: /pnfs/mu2e/scratch/users/myucel/BkgDiag10k.root
# Processed file /pnfs/mu2e/scratch/users/myucel/BkgDiag10k.root with 329247 hits
# Total dataset [ 5. 10. 11. ...  5.  4.  4.] hits, 280088 signal and 49159 background

# %%
min_len = min(len(input_dataset[signal]), len(input_dataset[backgnd]))
bsize=32
# I need to double the batch_size when truncating as we divide the sample in half later for training
tsize=2*bsize
min_len = min_len - min_len%tsize
print("Training on %s matched hits"%min_len)
signal_dataset = input_dataset[signal][:min_len]
bkg_dataset = input_dataset[backgnd][:min_len]

balanced_input = np.concatenate((signal_dataset, bkg_dataset))
y_balanced_input = np.concatenate((np.ones(signal_dataset.shape[0]), np.zeros(bkg_dataset.shape[0])))

n_variables = balanced_input.shape[1]

x_ce_train, x_ce_test, y_ce_train, y_ce_test = train_test_split(balanced_input, y_balanced_input, test_size=0.5, random_state=42)
x_ce_test, x_ce_valid, y_ce_test, y_ce_valid = train_test_split(x_ce_test, y_ce_test, test_size=0.5, random_state=42)
# Out:
# Training on 49152 matched hits

# %%
clusterrho_sig = []
zmin_sig = []
zmax_sig = []
zgap_sig = []
nplanes_sig = []
planefraction_sig = []
nhits_sig = []

for i in range(signal_dataset.shape[0]):
    clusterrho_sig.append(signal_dataset[i][0])
    
for i in range(signal_dataset.shape[0]):
    zmin_sig.append(signal_dataset[i][1])
    
for i in range(signal_dataset.shape[0]):
    zmax_sig.append(signal_dataset[i][2])

for i in range(signal_dataset.shape[0]):
    zgap_sig.append(signal_dataset[i][3])
    
for i in range(signal_dataset.shape[0]):
    nplanes_sig.append(signal_dataset[i][4])

for i in range(signal_dataset.shape[0]):
    planefraction_sig.append(signal_dataset[i][5])

for i in range(signal_dataset.shape[0]):
    nhits_sig.append(signal_dataset[i][6])

# %%
clusterrho_back = []
zmin_back = []
zmax_back = []
zgap_back = []
nplanes_back = []
planefraction_back = []
nhits_back = []

for i in range(bkg_dataset.shape[0]):
    clusterrho_back.append(bkg_dataset[i][0])
    
for i in range(bkg_dataset.shape[0]):
    zmin_back.append(bkg_dataset[i][1])
    
for i in range(bkg_dataset.shape[0]):
    zmax_back.append(bkg_dataset[i][2])

for i in range(bkg_dataset.shape[0]):
    zgap_back.append(bkg_dataset[i][3])

for i in range(bkg_dataset.shape[0]):
    nplanes_back.append(bkg_dataset[i][4])
    
for i in range(bkg_dataset.shape[0]):
    planefraction_back.append(bkg_dataset[i][5])
    
for i in range(bkg_dataset.shape[0]):
    nhits_back.append(bkg_dataset[i][6])

# %%
plt.hist(clusterrho_sig,label="Cluster Rho Signal", bins=400,range=(350,750))
plt.hist(clusterrho_back,label="Cluster Rho Background", histtype='step', bins=400,range=(350,700))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(zmin_sig,label="z_{min} Signal", bins=320,range=(-1600.0,1600.0))
plt.hist(zmin_back,label="z_{min} Background", histtype='step', bins=320, range=(-1600.0,1600.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(zmax_sig,label="z_{max} Signal", bins=320,range=(-1600.0,1600.0))
plt.hist(zmax_back,label="z_{max} Background", histtype='step', bins=320, range=(-1600.0,1600.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(zgap_sig,label="z_{gap} Signal", bins=320,range=(0.0,3200.0))
plt.hist(zgap_back,label="z_{gap} Background", histtype='step', bins=320, range=(0.0,3200.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(nplanes_sig,label="# of Planes Signal",bins=40,range=(0,40.0))
plt.hist(nplanes_back,label="# of Planes Background", histtype='step', bins=40, range=(0,40.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(planefraction_sig,label="Plane Fraction Signal", bins=110, range=(0,1.1))
plt.hist(planefraction_back,label="Plane Fraction Background", histtype='step', bins=110, range=(0,1.1))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(nhits_sig,label="# of Hits Signal", bins=200, range=(0.0,200.0))
plt.hist(nhits_back,label="# of Hits Background", histtype='step', bins=200, range=(0.0,200.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Then, we concatenate each hit variables into a single, large numpy array. These arrays are then stacked in a single bi-dimensional array with `np.vstack`, which will be our input dataset used for the training of the machine learning algorithms.

# %% [markdown]
# Here we then assign a label to each hit as _signal_ or _background_, depending on the Monte Carlo truth information. Since the dimension of  `detshmc.rel._rel` is not guaranteed to be the same as the dimension of `detsh` we need to loop over all the entries.

# %% [markdown]
# ## Create and train a multi-layer perceptron

# %% [markdown]
# Here we create a _multi-layer perceptron_ (MLP) model which consists of 3 fully-connected (or _dense_) layers, each one followed by a _dropout_ layer, which helps to avoid overfitting. The model is trained using the [Adam](https://arxiv.org/abs/1412.6980) optimizer and trained for 50 epochs or until the validation loss doesn't improve for 5 epochs (`early_stop`). The model we save must be created first, with an explicit input layer with explicit batch_size, otherwise it can't be parsed by the TMVA::SOFIE parser we use to generate a C++ inference function downstream.

# %% [markdown]
# The output model must have batch_size=1, otherwise the SOFIE inference function will assume that many input variables at a time.  Training (gradient calculation) however is much more efficient with a larger batch size, so we construct a separate model for that.  After training and before saving, we'll copy the weights (which don't depend on batch_size) from the trained model to the output model.  This should be unnecessary in the next verison of ROOT.
#
# We should initialize the model by reading a previous iteration. TODO

# %%
lay0=Input(shape=(n_variables,),batch_size=1)
lay1=Dense(2*n_variables, activation='relu')(lay0)
lay2=Dense(2*n_variables, activation='relu')(lay1)
lay3=Dense(2*n_variables, activation='relu')(lay2)
lay4=Dense(1,activation='sigmoid')(lay3)
output_model=Model(inputs=lay0,outputs=lay4)

opt = Adam(learning_rate=1e-3)
input=Input(shape=(n_variables,),batch_size=bsize)
x=Dense(2*n_variables, activation='relu')(input)
x=Dense(2*n_variables, activation='relu')(x)
x=Dense(2*n_variables, activation='relu')(x)
output=Dense(1,activation='sigmoid')(x)
model_ce=Model(inputs=input,outputs=output)
model_ce.compile(loss='binary_crossentropy',metrics='accuracy',optimizer=opt)
early_stop = EarlyStopping(monitor='val_loss', patience=10, min_delta=1e-5, restore_best_weights=True)
history_ce = model_ce.fit(x_ce_train, y_ce_train,
                          batch_size=bsize,
                          epochs=200,
                          verbose=1,
                          validation_data=(x_ce_valid, y_ce_valid),
                          callbacks=[early_stop]
                         )
# Out:
# 2023-02-10 13:50:20.102166: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/ifdhc/v2_6_10/Linux64bit-3-10-2-17/lib:/mu2e/app/users/myucel/mu2e-dev/build/sl7-prof-e20-p037/Offline/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cryptopp/v08_02_00/Linux64bit+3.10-2.17-e20-prof:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/gcc/v9_3_0/Linux64bit+3.10-2.17/lib:/cvmfs/fermilab.opensciencegrid.org/products/common/db/../prd/curl/v7_64_1/Linux64bit-3-10/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cry/v1_7p/Linux64bit+3.10-2.17-e20-prof/cry_v1.7/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/KinKal/v02_03_01/slf7.x86_64.e20.p3913.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/BTrk/v1_02_37/slf7.x86_64.e20.prof.p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core_mu2e/v1_08_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pcie_linux_kernel_module/v2_07_00/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/artdaq_core/v3_09_03/slf7.x86_64.e20.s118.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/TRACE/v3_17_05//lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/geant4/v4_10_7_p03b/Linux64bit+3.10-2.17-e20-mt-prof/lib64:/cvmfs/mu2e.opensciencegrid.org/artexternals/xerces_c/v3_2_3c/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gallery/v1_20_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas_root_io/v1_11_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/xrootd/v5_4_3b/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/pythia/v6_4_28u/Linux64bit+3.10-2.17-gcc930-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/postgresql/v14_5/Linux64bit+3.10-2.17-p3913/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/openblas/v0_3_21/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/python/v3_9_13/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/libxml2/v2_9_12/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/gsl/v2_7/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fftw/v3_3_10/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/root/v6_26_06/Linux64bit+3.10-2.17-e20-p3913-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/art/v3_12_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/canvas/v3_14_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/messagefacility/v2_09_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/fhiclcpp/v4_17_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib/v3_16_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/sqlite/v3_39_02_00/Linux64bit+3.10-2.17/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/hep_concurrency/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/tbb/v2021_7_0/Linux64bit+3.10-2.17-e20/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/cetlib_except/v1_08_00/slf7.x86_64.e20.prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/boost/v1_80_0/Linux64bit+3.10-2.17-e20-prof/lib:/cvmfs/mu2e.opensciencegrid.org/artexternals/clhep/v2_4_5_3a/Linux64bit+3.10-2.17-e20-prof/lib
# 2023-02-10 13:50:20.102251: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-10 13:50:20.102307: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mu2egpvm02.fnal.gov): /proc/driver/nvidia/version does not exist
# 2023-02-10 13:50:20.112243: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 1536/1536 [==============================] - 5s 2ms/step - loss: 1.6383 - accuracy: 0.8012 - val_loss: 0.5095 - val_accuracy: 0.8424
# Epoch 2/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.4954 - accuracy: 0.8314 - val_loss: 0.4188 - val_accuracy: 0.8649
# Epoch 3/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.4408 - accuracy: 0.8436 - val_loss: 0.3674 - val_accuracy: 0.8689
# Epoch 4/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.4057 - accuracy: 0.8543 - val_loss: 0.4173 - val_accuracy: 0.8370
# Epoch 5/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3773 - accuracy: 0.8624 - val_loss: 0.3902 - val_accuracy: 0.8614
# Epoch 6/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3607 - accuracy: 0.8675 - val_loss: 0.3323 - val_accuracy: 0.8758
# Epoch 7/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3461 - accuracy: 0.8717 - val_loss: 0.3327 - val_accuracy: 0.8783
# Epoch 8/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3360 - accuracy: 0.8754 - val_loss: 0.3119 - val_accuracy: 0.8834
# Epoch 9/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3286 - accuracy: 0.8772 - val_loss: 0.3203 - val_accuracy: 0.8810
# Epoch 10/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3249 - accuracy: 0.8797 - val_loss: 0.3081 - val_accuracy: 0.8853
# Epoch 11/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3223 - accuracy: 0.8815 - val_loss: 0.3166 - val_accuracy: 0.8870
# Epoch 12/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3211 - accuracy: 0.8818 - val_loss: 0.3104 - val_accuracy: 0.8811
# Epoch 13/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3176 - accuracy: 0.8834 - val_loss: 0.3262 - val_accuracy: 0.8800
# Epoch 14/200
# 1536/1536 [==============================] - 4s 2ms/step - loss: 0.3181 - accuracy: 0.8841 - val_loss: 0.3061 - val_accuracy: 0.8868
# Epoch 15/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3161 - accuracy: 0.8831 - val_loss: 0.3034 - val_accuracy: 0.8826
# Epoch 16/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3137 - accuracy: 0.8851 - val_loss: 0.3386 - val_accuracy: 0.8808
# Epoch 17/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3118 - accuracy: 0.8857 - val_loss: 0.3022 - val_accuracy: 0.8868
# Epoch 18/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3107 - accuracy: 0.8864 - val_loss: 0.2999 - val_accuracy: 0.8893
# Epoch 19/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3067 - accuracy: 0.8874 - val_loss: 0.3228 - val_accuracy: 0.8881
# Epoch 20/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.3064 - accuracy: 0.8880 - val_loss: 0.2983 - val_accuracy: 0.8899
# Epoch 21/200
# 1536/1536 [==============================] - 5s 3ms/step - loss: 0.3011 - accuracy: 0.8893 - val_loss: 0.2996 - val_accuracy: 0.8946
# Epoch 22/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2980 - accuracy: 0.8915 - val_loss: 0.2916 - val_accuracy: 0.8897
# Epoch 23/200
# 1536/1536 [==============================] - 4s 2ms/step - loss: 0.2972 - accuracy: 0.8905 - val_loss: 0.2902 - val_accuracy: 0.8983
# Epoch 24/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2981 - accuracy: 0.8918 - val_loss: 0.2878 - val_accuracy: 0.8931
# Epoch 25/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2960 - accuracy: 0.8921 - val_loss: 0.2913 - val_accuracy: 0.8907
# Epoch 26/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2944 - accuracy: 0.8916 - val_loss: 0.2987 - val_accuracy: 0.8890
# Epoch 27/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2937 - accuracy: 0.8932 - val_loss: 0.2886 - val_accuracy: 0.8964
# Epoch 28/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2921 - accuracy: 0.8924 - val_loss: 0.2944 - val_accuracy: 0.8972
# Epoch 29/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2944 - accuracy: 0.8926 - val_loss: 0.2931 - val_accuracy: 0.8975
# Epoch 30/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2920 - accuracy: 0.8936 - val_loss: 0.2860 - val_accuracy: 0.8975
# Epoch 31/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2907 - accuracy: 0.8946 - val_loss: 0.2809 - val_accuracy: 0.8986
# Epoch 32/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2887 - accuracy: 0.8960 - val_loss: 0.2816 - val_accuracy: 0.8951
# Epoch 33/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2900 - accuracy: 0.8947 - val_loss: 0.2831 - val_accuracy: 0.8953
# Epoch 34/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2888 - accuracy: 0.8950 - val_loss: 0.2870 - val_accuracy: 0.8941
# Epoch 35/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2872 - accuracy: 0.8951 - val_loss: 0.2845 - val_accuracy: 0.8950
# Epoch 36/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2858 - accuracy: 0.8965 - val_loss: 0.2870 - val_accuracy: 0.8965
# Epoch 37/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2856 - accuracy: 0.8961 - val_loss: 0.2787 - val_accuracy: 0.8993
# Epoch 38/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2858 - accuracy: 0.8969 - val_loss: 0.2756 - val_accuracy: 0.9017
# Epoch 39/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2837 - accuracy: 0.8976 - val_loss: 0.2961 - val_accuracy: 0.8945
# Epoch 40/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2838 - accuracy: 0.8973 - val_loss: 0.2783 - val_accuracy: 0.8999
# Epoch 41/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2838 - accuracy: 0.8970 - val_loss: 0.2829 - val_accuracy: 0.8967
# Epoch 42/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2832 - accuracy: 0.8977 - val_loss: 0.2756 - val_accuracy: 0.9014
# Epoch 43/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2818 - accuracy: 0.8981 - val_loss: 0.2747 - val_accuracy: 0.8994
# Epoch 44/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2828 - accuracy: 0.8989 - val_loss: 0.2794 - val_accuracy: 0.9016
# Epoch 45/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2821 - accuracy: 0.8987 - val_loss: 0.2795 - val_accuracy: 0.9013
# Epoch 46/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2813 - accuracy: 0.8981 - val_loss: 0.2765 - val_accuracy: 0.8985
# Epoch 47/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2812 - accuracy: 0.8982 - val_loss: 0.2764 - val_accuracy: 0.8968
# Epoch 48/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2791 - accuracy: 0.8982 - val_loss: 0.2732 - val_accuracy: 0.9008
# Epoch 49/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2794 - accuracy: 0.8995 - val_loss: 0.2702 - val_accuracy: 0.9004
# Epoch 50/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2789 - accuracy: 0.8985 - val_loss: 0.2848 - val_accuracy: 0.9022
# Epoch 51/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2773 - accuracy: 0.8996 - val_loss: 0.2727 - val_accuracy: 0.9000
# Epoch 52/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2772 - accuracy: 0.8989 - val_loss: 0.2727 - val_accuracy: 0.9025
# Epoch 53/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2766 - accuracy: 0.8997 - val_loss: 0.2814 - val_accuracy: 0.8966
# Epoch 54/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2773 - accuracy: 0.8992 - val_loss: 0.2868 - val_accuracy: 0.9019
# Epoch 55/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2767 - accuracy: 0.9004 - val_loss: 0.2649 - val_accuracy: 0.9038
# Epoch 56/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2753 - accuracy: 0.9006 - val_loss: 0.2718 - val_accuracy: 0.9008
# Epoch 57/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2756 - accuracy: 0.8996 - val_loss: 0.2678 - val_accuracy: 0.9028
# Epoch 58/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2744 - accuracy: 0.9010 - val_loss: 0.2797 - val_accuracy: 0.8995
# Epoch 59/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2743 - accuracy: 0.9006 - val_loss: 0.2746 - val_accuracy: 0.9008
# Epoch 60/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2741 - accuracy: 0.9000 - val_loss: 0.2676 - val_accuracy: 0.9052
# Epoch 61/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2740 - accuracy: 0.9007 - val_loss: 0.2687 - val_accuracy: 0.9064
# Epoch 62/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2740 - accuracy: 0.9006 - val_loss: 0.2628 - val_accuracy: 0.9047
# Epoch 63/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2744 - accuracy: 0.9003 - val_loss: 0.2771 - val_accuracy: 0.8956
# Epoch 64/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2729 - accuracy: 0.9017 - val_loss: 0.2689 - val_accuracy: 0.9049
# Epoch 65/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2732 - accuracy: 0.9009 - val_loss: 0.2670 - val_accuracy: 0.9053
# Epoch 66/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2732 - accuracy: 0.9002 - val_loss: 0.2715 - val_accuracy: 0.9025
# Epoch 67/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2736 - accuracy: 0.9010 - val_loss: 0.2623 - val_accuracy: 0.9046
# Epoch 68/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2736 - accuracy: 0.9011 - val_loss: 0.2709 - val_accuracy: 0.9034
# Epoch 69/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2725 - accuracy: 0.9011 - val_loss: 0.2628 - val_accuracy: 0.9026
# Epoch 70/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2711 - accuracy: 0.9009 - val_loss: 0.2659 - val_accuracy: 0.9020
# Epoch 71/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2718 - accuracy: 0.9014 - val_loss: 0.2746 - val_accuracy: 0.9004
# Epoch 72/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2728 - accuracy: 0.9006 - val_loss: 0.2643 - val_accuracy: 0.9052
# Epoch 73/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2710 - accuracy: 0.9010 - val_loss: 0.2707 - val_accuracy: 0.9034
# Epoch 74/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2704 - accuracy: 0.9020 - val_loss: 0.2637 - val_accuracy: 0.9045
# Epoch 75/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2705 - accuracy: 0.9010 - val_loss: 0.2629 - val_accuracy: 0.9064
# Epoch 76/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2708 - accuracy: 0.9012 - val_loss: 0.2641 - val_accuracy: 0.9051
# Epoch 77/200
# 1536/1536 [==============================] - 3s 2ms/step - loss: 0.2710 - accuracy: 0.9014 - val_loss: 0.2625 - val_accuracy: 0.9067

# %% [markdown]
# ## Create and train a Boosted Decision Tree
# Here, instead of using a MLP, we use a [_Gradient Boosted Decision Tree_](https://xgboost.readthedocs.io/en/stable/) (BDT) to distinguish between signal (true CE hits) and background (fake CE hits). We use the defualt hyperparameters.

# %%
model_xgboost = XGBClassifier()
model_xgboost.fit(x_ce_train, y_ce_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %% [markdown]
# Here we can finally apply our two models (the MLP and the BDT) to our test datasets and create the corresponding ROC curves.

# %%
#prediction_ce = model_ce.predict(x_ce_test).ravel()
prediction_ce = model_ce.predict(x_ce_test)
fpr_ce, tpr_ce, th_ce = roc_curve(y_ce_test,  prediction_ce)
auc_ce = roc_auc_score(y_ce_test, prediction_ce)
# Out:
# 768/768 [==============================] - 1s 997us/step

# %%
prediction_xgboost = model_xgboost.predict_proba(x_ce_test)[:,1]
fpr_xgboost, tpr_xgboost, th_xgboost = roc_curve(y_ce_test,  prediction_xgboost)
auc_xgboost = roc_auc_score(y_ce_test, prediction_xgboost)

# %% [markdown]
# The plot of the ROC curves clearly shows that the BDT outperforms the MLP. In principle, however, it should be possible to improve the MLP performances by optimizing the hyperparameters (learning rate, hidden layers, activation functions, etc.).

# %%
fig, ax = plt.subplots(1,1)
ax.plot(tpr_ce,1-fpr_ce,label=f'MLP AUC: {auc_ce:.4f}')
ax.plot(tpr_xgboost,1-fpr_xgboost,label=f'BDT AUC: {auc_xgboost:.4f}')

ax.legend()
ax.set_aspect("equal")
ax.set_xlabel("Signal efficiency")
ax.set_ylabel("Background rejection")
ax.set_xlim(0.8,1.05)
ax.set_ylim(0.8,1.05)
fig.savefig("TrainBkg.pdf")

# %% [markdown]
# Now we save our model in HDF5 format.  This can be used as input to the SOFIE parser.  Note that the kernel must be restarted when saving this file, as re-running individual cells increments the layer numbers in the hdf5 file, causing the SOFIE parser to fail.  This causes the spurious tensorflow warning about the model not having been built.

# %%
output_model.set_weights(model_ce.get_weights())
output_model.summary()
output_model.save("TrainBkg.h5")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 7)]                  0
#
#  dense (Dense)               (1, 14)                   112
#
#  dense_1 (Dense)             (1, 14)                   210
#
#  dense_2 (Dense)             (1, 14)                   210
#
#  dense_3 (Dense)             (1, 1)                    15
#
# =================================================================
# Total params: 547
# Trainable params: 547
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
